# %% [markdown]
# # Loading and Reading LIDC-IDRI

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Installation and Configuration

# %%
# %pip install pylidc
# Out:
# Requirement already satisfied: pylidc in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (0.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: sqlalchemy>=1.1.5 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (2.0.41)
# Requirement already satisfied: numpy>=1.12.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (2.2.5)
# Requirement already satisfied: scipy>=0.18.1 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (1.15.3)
# Requirement already satisfied: matplotlib>=2.0.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (3.10.3)
# Requirement already satisfied: pydicom>=1.0.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (3.0.1)
# Requirement already satisfied: scikit-image>=0.13 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from pylidc) (0.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (25.0)
# Requirement already satisfied: pillow>=8 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from matplotlib>=2.0.0->pylidc) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pylidc) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from scikit-image>=0.13->pylidc) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from scikit-image>=0.13->pylidc) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from scikit-image>=0.13->pylidc) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from scikit-image>=0.13->pylidc) (0.4)
# Requirement already satisfied: greenlet>=1 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from sqlalchemy>=1.1.5->pylidc) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\basesdatos\lidc-idri-preprocessing\env\lib\site-packages (from sqlalchemy>=1.1.5->pylidc) (4.13.2)

# %%
import pylidc as pl

path = '../LIDC-IDRI/LIDC-IDRI-0001'
f = open('/root/.pylidcrc', 'w')
f.write(f'[dicom]\npath = {path}\n\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import pylidc as pl
#       3 path = '../LIDC-IDRI/LIDC-IDRI-0001'
# ----> 4 f = open('/root/.pylidcrc', 'w')
#       5 f.write(f'[dicom]\npath = {path}\n\n')
#       6 f.close()
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.pylidcrc'

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.set_cmap('gray')

# %% [markdown]
# ---

# %% [markdown]
# ## Accessing Scans

# %% [markdown]
# In this subset, only patients 1 through 30 are accessible.

# %%
pid = 'LIDC-IDRI-0001'
scan = pl.query(pl.Scan).filter(pl.Scan.patient_id == pid).first()

# %%
vol = scan.to_volume()
print(vol.shape) # (dim, dim, depth)

plt.figure(figsize=(5, 5))
plt.imshow(vol[:,:,0])
plt.show() # show the first-level slice
# Out:
# Loading dicom files ... This may take a moment.
# (512, 512, 133)

# %%
# uncomment for an interactive visualization across depth cross-sections

# scan.visualize(annotation_groups=scan.cluster_annotations())

# %% [markdown]
# ## Accessing Annotations

# %%
pid = 'LIDC-IDRI-0001'
annot = pl.query(pl.Annotation).filter(pl.Scan.patient_id == pid).first()
# Out:
# C:\Users\Claudio\AppData\Local\Temp\ipykernel_28560\4051012190.py:2: SAWarning: SELECT statement has a cartesian product between FROM element(s) "annotations" and FROM element "scans".  Apply join condition(s) between each element to resolve.
#   annot = pl.query(pl.Annotation).filter(pl.Scan.patient_id == pid).first()

# %%
annot.print_formatted_feature_table()
# Out:
# Feature              Meaning                    #
# -                    -                          -
# Subtlety           | Obvious                  | 5
# Internalstructure  | Soft Tissue              | 1
# Calcification      | Absent                   | 6
# Sphericity         | Ovoid                    | 3
# Margin             | Near Sharp               | 4
# Lobulation         | No Lobulation            | 1
# Spiculation        | No Spiculation           | 1
# Texture            | Solid                    | 5
# Malignancy         | Indeterminate            | 3

# %%
padding = [(10, 10), (25, 25), (0, 0)]

masks = annot.boolean_mask(pad = padding)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 padding = [(10, 10), (25, 25), (0, 0)]
# ----> 3 masks = annot.boolean_mask(pad = padding)
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Annotation.py:1003, in Annotation.boolean_mask(self, pad, bbox, include_contour_points)
#     964 def boolean_mask(self, pad=None, bbox=None, include_contour_points=False):
#     965     """
#     966     A boolean volume where 1 indicates nodule and 0 indicates
#     967     non-nodule. The `mask` volume covers the extent of the voxels
#    (...)
#    1001         # => Avg HU outside nodule: -732.2
#    1002     """
# -> 1003     bb = self.bbox_matrix(pad=pad) if bbox is None else bbox
#    1005     czs = self.contour_slice_zvals
#    1006     cks = self.contour_slice_indices
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Annotation.py:556, in Annotation.bbox_matrix(self, pad)
#     515 def bbox_matrix(self, pad=None):
#     516     """
#     517     The `bbox` function returns a tuple of slices to be used to index
#     518     into an image volume. On the other hand, `bbox_array` returns
#    (...)
#     554         # => True
#     555     """
# --> 556     return np.array([[sl.start, sl.stop-1] for sl in self.bbox(pad=pad)])
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Annotation.py:425, in Annotation.bbox(self, pad)
#     422 # The index limits for the scan.
#     423 limits = [(0,511), (0,511), (0,self.scan.slice_zvals.shape[0]-1)]
# --> 425 cmatrix = self.contours_matrix
#     426 imin,jmin,kmin = cmatrix.min(axis=0)
#     427 imax,jmax,kmax = cmatrix.max(axis=0)
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Annotation.py:960, in Annotation.contours_matrix(self)
#     955 @property
#     956 def contours_matrix(self):
#     957     """
#     958     All the contour index values a 3D numpy array.
#     959     """
# --> 960     return np.vstack([c.to_matrix(include_k=True)
#     961                             for c in sorted(self.contours,
#     962                                     key=lambda c: c.image_z_position)])
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Annotation.py:960, in <listcomp>(.0)
#     955 @property
#     956 def contours_matrix(self):
#     957     """
#     958     All the contour index values a 3D numpy array.
#     959     """
# --> 960     return np.vstack([c.to_matrix(include_k=True)
#     961                             for c in sorted(self.contours,
#     962                                     key=lambda c: c.image_z_position)])
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\pylidc\Contour.py:111, in Contour.to_matrix(self, include_k)
#     109 k  = np.ones(ij.shape[0])*self.image_k_position
#     110 zs = self.annotation.contour_slice_zvals
# --> 111 return np.c_[ij, k].astype(np.int)
#
# File d:\BasesDatos\LIDC-IDRI-Preprocessing\env\lib\site-packages\numpy\__init__.py:410, in __getattr__(attr)
#     405     warnings.warn(
#     406         f"In the future `np.{attr}` will be defined as the "
#     407         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     409 if attr in __former_attrs__:
# --> 410     raise AttributeError(__former_attrs__[attr], name=None)
#     412 if attr in __expired_attributes__:
#     413     raise AttributeError(
#     414         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     415         f"{__expired_attributes__[attr]}",
#     416         name=None
#     417     )
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
padding = [(10, 10), (25, 25), (0, 0)]

masks = annot.boolean_mask(pad = padding)
bbox = annot.bbox(pad = padding)
relevant_vol = vol[bbox]

for region in range(masks.shape[2]):
    
    plt.figure(figsize=(10, 5), dpi=400)
    plt.subplot(1, 2, 1)
    plt.imshow(relevant_vol[:,:,region])
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(masks[:,:,region])
    plt.axis('off')
    plt.show()
    plt.close()

# %% [markdown]
# ---

# %% [markdown]
# ## Accessing Annotations by Annotator

# %%
from pylidc.utils import consensus
from skimage.measure import find_contours

# %%
scan = pl.query(pl.Scan).filter(pl.Scan.patient_id == 'LIDC-IDRI-0001').first()
vol = scan.to_volume()

nods = scan.cluster_annotations()
anns = nods[0]

cmask,cbbox,masks = consensus(anns, clevel=0.5,
                              pad=[(20,20), (20,20), (0,0)])
k = int(0.5*(cbbox[2].stop - cbbox[2].start))

# Set up the plot.
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.imshow(vol[cbbox][:,:,k], cmap=plt.cm.gray, alpha=0.5)

# Plot the annotation contours for the kth slice.
colors = ['r', 'g', 'b', 'y']
for j in range(len(masks)):
    for c in find_contours(masks[j][:,:,k].astype(float), 0.5):
        label = "Annotation %d" % (j+1)
        plt.plot(c[:,1], c[:,0], colors[j], label=label)

# Plot the 50% consensus contour for the kth slice.
for c in find_contours(cmask[:,:,k].astype(float), 0.5):
    plt.plot(c[:,1], c[:,0], '--k', label='50% Consensus')

ax.axis('off')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Loading dicom files ... This may take a moment.
